# %% [markdown]
# # **Yeison Bermudez**
#
#
# **1751400**
#
#
# **Cuaderno #9 - Análisis exploratorio**
#
#
# **22 de Noviembre del 2019**

# %% [markdown]
# Preparación de los datos.

# %%
import pandas as pd
df = pd.read_csv('files/indicadores-mundiales.csv', encoding='latin-1')
df.head()
# Out:
#          Ano  Dias para iniciar un negocio  Emisiones de CO2  \
# 0  12/1/2000                           NaN           87931.0
# 1  12/1/2000                           NaN            9542.0
# 2  12/1/2000                           NaN            1617.0
# 3  12/1/2000                           NaN            4276.0
# 4  12/1/2000                           NaN            1041.0
#
#    Esperanza de vida (mujeres)  Esperanza de vida (varones)  \
# 0                         71.0                         67.0
# 1                         47.0                         44.0
# 2                         57.0                         53.0
# 3                         52.0                         49.0
# 4                         52.0                         49.0
#
#    Facilidad para hacer negocios  Gasto en salud ( del PIB)  \
# 0                            NaN                        3.5
# 1                            NaN                        3.4
# ...

# %% [markdown]
# El análisis exploratorio se usa para describir propiedades de los datos:
#
# * Localización de los datos.
# * Dispersión de los datos.
# * Distribución de los datos.
# * Relaciones entre los datos.
#
# Pero en términos de la analítica y la inteligencia de negocios, también se usa para responder  preguntas sobre los datos, cuyas respuestas dan insights.
#
# Realice los siguientes ejercicios:
#
# **Ejercicio 1.**-- Construya una tabla de las emisiones de CO2 por continente.
#
# **Ejercicio 2.**-- Cuántos registros hay con datos faltantes?
#
# **Ejercicio 3.**-- Cuáles son los países con menores gastos de salud por región?.
#
# **Ejercicio 4.**-- Cuál es el país con menor esperanza de vida para las mujeres?
#
# **Ejercicio 5.**-- Cuáles son los 10 países con la menor cantidad de población entre 0 y 14 y a cuál región pertenecen?
#
# **Ejercicio 6.**-- Haga un diagrama de barras de las emisiones de CO2 por continente (en los siguientes tutoriales son sobre graficación).
#
# **Ejercicio 7.**-- Haga un boxplot de las emisiones de CO2 por continente (los siguientes tutoriales son sobre graficación).
